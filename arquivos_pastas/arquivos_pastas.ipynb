# %% [markdown]
# ### Listar arquivos pasta:

# %%
#bliblioteca 
from pathlib import Path

print(Path.cwd())

caminho = Path('arquivos_lojas')
arquivos = caminho.iterdir()
for arquivo in arquivos:
    print(arquivo)
# Out:
# C:\Users\mauyr\Python\aulas_hashtag\arquivos_pastas
# arquivos_lojas\AM
# arquivos_lojas\GO
# arquivos_lojas\MG
# arquivos_lojas\RJ
# arquivos_lojas\SP

# %% [markdown]
# ### Saber se o arquivo existe

# %%
#  BARRA JUNTA O CAMINHO C O PATH
if (caminho / Path ('201801_Amazonas Shopping_AM.csv')).exists():
    print('Existe')

# %% [markdown]
# ### Criando pasta nova

# %%
if !(Path ('pasta_nova').exists()):
    Path ('pasta_nova').mkdir()

# %% [markdown]
# ### Criando uma cópia do nosso arquivo na nova pasta que criamos

# %%
#biblioteca shutil melhor para mover pastas 
import shutil
arquivo_copiar = Path('arquivos_lojas/201801_Amazonas Shopping_AM.csv')
arquivo_colar = Path('pasta_nova/201801_Amazonas Shopping_AM_versao2.csv')
shutil.copy2(arquivo_copiar, arquivo_colar)
# Out:
# WindowsPath('pasta_nova/201801_Amazonas Shopping_AM_versao2.csv')

# %% [markdown]
# ### Movendo um arquivo de um lugar para o outro

# %%
shutil.move(Path('pasta_nova/201801_Amazonas Shopping_AM_versao2.csv'), Path('Pasta_nova/201801_Amazonas Shopping_AM_versao2.csv'))
# Out:
# WindowsPath('Pasta_nova/201801_Amazonas Shopping_AM_versao2.csv')

# %% [markdown]
# ### DESAFIO ORGANIZANDO PASTAS POR ESTADO

# %%
from pathlib import Path
import shutil

estados = ['RJ', 'SP', 'MG', 'GO', 'AM']
for estado in estados:
       Path('arquivos_lojas/{}'.format(estado)).mkdir()
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-11-c0232dff75e0> in <module>
#       4 estados = ['RJ', 'SP', 'MG', 'GO', 'AM']
#       5 for estado in estados:
# ----> 6        Path('arquivos_lojas/{}'.format(estado)).mkdir()
#
# ~\anaconda3\lib\pathlib.py in mkdir(self, mode, parents, exist_ok)
#    1282             self._raise_closed()
#    1283         try:
# -> 1284             self._accessor.mkdir(self, mode)
#    1285         except FileNotFoundError:
#    1286             if not parents or self.parent == self:
#
# FileExistsError: [WinError 183] Não é possível criar um arquivo já existente: 'arquivos_lojas\\RJ'

# %%
caminho = Path('arquivos_lojas/')
arquivos = caminho.iterdir()
for arquivo in arquivos:
    nome_arquivo = arquivo.name
    if nome_arquivo[-3:] == 'csv':
        estado = nome_arquivo[-6:-4]
        local_final = caminho / Path('{}/{}'.format(estado, nome_arquivo))
        shutil.move(arquivo, local_final)
